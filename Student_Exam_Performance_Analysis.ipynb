# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading Dataset

# %%
data = pd.read_csv('/content/Student_Performance_Factors (raw_data).csv')
data.head()
# Out:
#    Student_id  Hours_Studied  Attendance Parental_Involvement  \
# 0        1001             23          84                  Low
# 1        1002             19          64                  Low
# 2        1003             24          98               Medium
# 3        1004             29          89                  Low
# 4        1005             19          92               Medium
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
# 2              Medium                        Yes            7
# 3              Medium                        Yes            8
# 4              Medium                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  ...  Family_Income  \
# 0               73              Low             Yes  ...            Low
# 1               59              Low             Yes  ...         Medium
# 2               91           Medium             Yes  ...         Medium
# 3               98           Medium             Yes  ...         Medium
# 4               65           Medium             Yes  ...         Medium
#
#   Teacher_Quality School_Type Peer_Influence Physical_Activity  \
# 0          Medium      Public       Positive                 3
# 1          Medium      Public       Negative                 4
# 2          Medium      Public        Neutral                 4
# 3          Medium      Public       Negative                 4
# 4            High      Public        Neutral                 4
#
#    Learning_Disabilities Parental_Education_Level Distance_from_Home  Gender  \
# 0                     No              High School               Near    Male
# 1                     No                  College           Moderate  Female
# 2                     No             Postgraduate               Near    Male
# 3                     No              High School           Moderate    Male
# 4                     No                  College               Near  Female
#
#   Exam_Score
# 0         67
# 1         61
# 2         74
# 3         71
# 4         70
#
# [5 rows x 21 columns]

# %%
df = data.copy()

# %% [markdown]
# Check for Null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_id                  6607 non-null   int64
#  1   Hours_Studied               6607 non-null   int64
#  2   Attendance                  6607 non-null   int64
#  3   Parental_Involvement        6607 non-null   object
#  4   Access_to_Resources         6607 non-null   object
#  5   Extracurricular_Activities  6607 non-null   object
#  6   Sleep_Hours                 6607 non-null   int64
#  7   Previous_Scores             6607 non-null   int64
#  8   Motivation_Level            6607 non-null   object
#  9   Internet_Access             6607 non-null   object
#  10  Tutoring_Sessions           6607 non-null   int64
#  11  Family_Income               6607 non-null   object
#  12  Teacher_Quality             6529 non-null   object
#  13  School_Type                 6607 non-null   object
#  14  Peer_Influence              6607 non-null   object
#  15  Physical_Activity           6607 non-null   int64
#  16  Learning_Disabilities       6607 non-null   object
#  17  Parental_Education_Level    6517 non-null   object
#  18  Distance_from_Home          6540 non-null   object
#  19  Gender                      6607 non-null   object
#  20  Exam_Score                  6607 non-null   int64
# dtypes: int64(8), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# Rearranging the columns

# %%
data.columns.values
# Out:
# array(['Student_id', 'Hours_Studied', 'Attendance',
#        'Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Sleep_Hours', 'Previous_Scores',
#        'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions',
#        'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'], dtype=object)

# %%
col_names = [
    'Student_id',
    'Gender',
    'School_Type',
    'Parental_Involvement',
    'Parental_Education_Level',
    'Motivation_Level',
    'Teacher_Quality',
    'Peer_Influence',
    'Distance_from_Home',
    'Internet_Access',
    'Access_to_Resources',
    'Extracurricular_Activities',
    'Learning_Disabilities',
    'Family_Income',
    'Hours_Studied',
    'Attendance',
    'Sleep_Hours',
    'Physical_Activity',
    'Previous_Scores',
    'Tutoring_Sessions',
    'Exam_Score'
]

df = df[col_names]
df.head()
# Out:
#    Student_id  Gender School_Type Parental_Involvement  \
# 0        1001    Male      Public                  Low
# 1        1002  Female      Public                  Low
# 2        1003    Male      Public               Medium
# 3        1004    Male      Public                  Low
# 4        1005  Female      Public               Medium
#
#   Parental_Education_Level Motivation_Level Teacher_Quality Peer_Influence  \
# 0              High School              Low          Medium       Positive
# 1                  College              Low          Medium       Negative
# 2             Postgraduate           Medium          Medium        Neutral
# 3              High School           Medium          Medium       Negative
# 4                  College           Medium            High        Neutral
#
#   Distance_from_Home Internet_Access  ... Extracurricular_Activities  \
# 0               Near             Yes  ...                         No
# 1           Moderate             Yes  ...                         No
# 2               Near             Yes  ...                        Yes
# 3           Moderate             Yes  ...                        Yes
# 4               Near             Yes  ...                        Yes
#
#   Learning_Disabilities Family_Income Hours_Studied  Attendance  Sleep_Hours  \
# 0                    No           Low            23          84            7
# 1                    No        Medium            19          64            8
# 2                    No        Medium            24          98            7
# 3                    No        Medium            29          89            8
# 4                    No        Medium            19          92            6
#
#    Physical_Activity  Previous_Scores  Tutoring_Sessions  Exam_Score
# 0                  3               73                  0          67
# 1                  4               59                  2          61
# 2                  4               91                  2          74
# 3                  4               98                  1          71
# 4                  4               65                  3          70
#
# [5 rows x 21 columns]

# %% [markdown]
# Check duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates
df = df.drop_duplicates()

# Confirm
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Handling Missing Values

# %% [markdown]
# *Exam_Score*

# %%
df['Exam_Score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset=['Exam_Score'])

# %% [markdown]
# *Attendance*

# %%
df['Attendance'].isnull().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset=['Attendance'])

# %% [markdown]
# *Hours_Studied*

# %%
df['Hours_Studied'].isnull().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset=['Hours_Studied'])

# %% [markdown]
# *Previous_Scores*

# %%
df['Previous_Scores'].isnull().sum()
# Out:
# np.int64(0)

# %%
median_prev_score = df['Previous_Scores'].median()
df['Previous_Scores'] = df['Previous_Scores'].fillna(median_prev_score)

# %% [markdown]
# *Motivation_Level*

# %%
df['Motivation_Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Motivation_Level'] = df['Motivation_Level'].fillna("Unknown")

# %% [markdown]
# *Tutoring_Sessions*

# %%
df['Tutoring_Sessions'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Tutoring_Sessions'] = df['Tutoring_Sessions'].fillna(0)

# %% [markdown]
# *CREATE ENGINEERED COLUMN – Performance_Level*

# %%
def performance_level(score):
    if score >= 75:
        return "Top Performer"
    elif score >= 50:
        return "Average Performer"
    else:
        return "Weak Performer"

df['Performance_Level'] = df['Exam_Score'].apply(performance_level)

# %%
df['Score_per_Hour'] = df['Exam_Score'] / df['Hours_Studied']

# %%
df[
    ['Exam_Score', 'Attendance', 'Hours_Studied',
     'Previous_Scores', 'Motivation_Level',
     'Tutoring_Sessions', 'Performance_Level']
].isnull().sum()
# Out:
# Exam_Score           0
# Attendance           0
# Hours_Studied        0
# Previous_Scores      0
# Motivation_Level     0
# Tutoring_Sessions    0
# Performance_Level    0
# dtype: int64

# %%
df.head()
# Out:
#    Student_id  Gender School_Type Parental_Involvement  \
# 0        1001    Male      Public                  Low
# 1        1002  Female      Public                  Low
# 2        1003    Male      Public               Medium
# 3        1004    Male      Public                  Low
# 4        1005  Female      Public               Medium
#
#   Parental_Education_Level Motivation_Level Teacher_Quality Peer_Influence  \
# 0              High School              Low          Medium       Positive
# 1                  College              Low          Medium       Negative
# 2             Postgraduate           Medium          Medium        Neutral
# 3              High School           Medium          Medium       Negative
# 4                  College           Medium            High        Neutral
#
#   Distance_from_Home Internet_Access  ... Family_Income Hours_Studied  \
# 0               Near             Yes  ...           Low            23
# 1           Moderate             Yes  ...        Medium            19
# 2               Near             Yes  ...        Medium            24
# 3           Moderate             Yes  ...        Medium            29
# 4               Near             Yes  ...        Medium            19
#
#   Attendance Sleep_Hours  Physical_Activity  Previous_Scores  \
# 0         84           7                  3               73
# 1         64           8                  4               59
# 2         98           7                  4               91
# 3         89           8                  4               98
# 4         92           6                  4               65
#
#    Tutoring_Sessions  Exam_Score  Performance_Level  Score_per_Hour
# 0                  0          67  Average Performer        2.913043
# 1                  2          61  Average Performer        3.210526
# 2                  2          74  Average Performer        3.083333
# 3                  1          71  Average Performer        2.448276
# 4                  3          70  Average Performer        3.684211
#
# [5 rows x 23 columns]

# %% [markdown]
# # Clean Data Checkpoint

# %%
clean_df = df.copy()
clean_df.head()
# Out:
#    Student_id  Gender School_Type Parental_Involvement  \
# 0        1001    Male      Public                  Low
# 1        1002  Female      Public                  Low
# 2        1003    Male      Public               Medium
# 3        1004    Male      Public                  Low
# 4        1005  Female      Public               Medium
#
#   Parental_Education_Level Motivation_Level Teacher_Quality Peer_Influence  \
# 0              High School              Low          Medium       Positive
# 1                  College              Low          Medium       Negative
# 2             Postgraduate           Medium          Medium        Neutral
# 3              High School           Medium          Medium       Negative
# 4                  College           Medium            High        Neutral
#
#   Distance_from_Home Internet_Access  ... Family_Income Hours_Studied  \
# 0               Near             Yes  ...           Low            23
# 1           Moderate             Yes  ...        Medium            19
# 2               Near             Yes  ...        Medium            24
# 3           Moderate             Yes  ...        Medium            29
# 4               Near             Yes  ...        Medium            19
#
#   Attendance Sleep_Hours  Physical_Activity  Previous_Scores  \
# 0         84           7                  3               73
# 1         64           8                  4               59
# 2         98           7                  4               91
# 3         89           8                  4               98
# 4         92           6                  4               65
#
#    Tutoring_Sessions  Exam_Score  Performance_Level  Score_per_Hour
# 0                  0          67  Average Performer        2.913043
# 1                  2          61  Average Performer        3.210526
# 2                  2          74  Average Performer        3.083333
# 3                  1          71  Average Performer        2.448276
# 4                  3          70  Average Performer        3.684211
#
# [5 rows x 23 columns]

# %%
clean_df.to_excel('stud_perf_factor_clean_data.xlsx', index=False)
clean_df.to_csv('stud_perf_factor_clean_data.csv', index=False)

# %%
df['Parental_Education_Level'].isnull().sum()
# Out:
# np.int64(90)

# %%
df['Parental_Education_Level'].unique()
# Out:
# array(['High School', 'College', 'Postgraduate', nan], dtype=object)

# %%
df.columns.values
# Out:
# array(['Student_id', 'Gender', 'School_Type', 'Parental_Involvement',
#        'Parental_Education_Level', 'Motivation_Level', 'Teacher_Quality',
#        'Peer_Influence', 'Distance_from_Home', 'Internet_Access',
#        'Access_to_Resources', 'Extracurricular_Activities',
#        'Learning_Disabilities', 'Family_Income', 'Hours_Studied',
#        'Attendance', 'Sleep_Hours', 'Physical_Activity',
#        'Previous_Scores', 'Tutoring_Sessions', 'Exam_Score',
#        'Performance_Level', 'Score_per_Hour'], dtype=object)
